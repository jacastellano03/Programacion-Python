# %%
# Ejercicio 2
# Escribir un programa que almacene la cadena de caracteres contraseña en una variable, pregunte al usuario por la contraseña e imprima por pantalla si la contraseña introducida por el usuario coincide con la guardada en la variable sin tener en cuenta mayúsculas y minúsculas.
"""
loggin = str(input("Ingrese su contraseña:"))

my_password = ("shajaeea")

if my_password == loggin.lower():
    print("Acceso Correcto")

else:
    print('Acceso Denegado CONTRASEÑA INCORRECTA')


my_password = "shajaeea"
loggin = input("Ingrese su contraseña:").lower()

if my_password == login:
    print("Acceso Correcto")

else:
    print("Acceso Denegado")
"""

loggin = str(input("Ingrese su contraseña:"))

my_password = ("ShaJaeea")

if my_password.casefold() == loggin.casefold():         # este casefold hace practicamente los mismo que lower solo que maneja mejor algunos caracteres especiales de otros idiomas
    print("Acceso Correcto")     
    
else:
    print("Acceso Denegado")
    
print(my_password.casefold())
print(loggin.casefold())
# Out:
# Ingrese su contraseña: SHAJAEEA
# Acceso Correcto
# shajaeea
# shajaeea
