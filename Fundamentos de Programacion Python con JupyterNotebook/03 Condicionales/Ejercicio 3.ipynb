# %%
# Ejercicio 3
# Escribir un programa que pida al usuario dos números y muestre por pantalla su división. Si el divisor es cero el programa debe mostrar un error.

number1 = float(input("Ingrese el primer numero"))
number2 = float(input("Ingrese el segundo numero"))

if number2 == 0:
    print("Error: digita un numero diferente de cero")
                
else:
    print("El resultado es:",number1/number2)
# Out:
# Ingrese el primer numero 10
# Ingrese el segundo numero 0
# Error: digita un numero diferente de cero
