# %%
# Ejercicio 13
# Escribir un programa que pregunte por una muestra de números, separados por comas, los guarde en una lista y muestre por pantalla su media y desviación típica.

datos = input("Ingrese números separados por comas: ")

lista = datos.split(",")

numeros = []

for elemento in lista:
    numeros.append(float(elemento))

media = sum(numeros) / len(numeros)

suma = 0

for numero in numeros:
    suma = suma + (numero - media) ** 2

desviacion = (suma / len(numeros)) ** 0.5

print("Media:", media)
print("Desviación típica:", desviacion)
# Out:
# Ingrese números separados por comas:  19,23,45,43,34,23
# Media: 31.166666666666668
# Desviación típica: 10.172129679778086
