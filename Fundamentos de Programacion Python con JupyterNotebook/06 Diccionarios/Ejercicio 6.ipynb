# %%
# Ejercicio 6
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario. Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

persona = {}

nombre = input("Nombre: ")
persona["Nombre"] = nombre
print(persona)

edad = input("Edad: ")
persona["Edad"] = edad
print(persona)

sexo = input("Sexo: ")
persona["Sexo"] = sexo
print(persona)

telefono = input("Teléfono: ")
persona["Teléfono"] = telefono
print(persona)

correo = input("Correo: ")
persona["Correo"] = correo
print(persona)
# Out:
# Nombre:  Alejandro
# {'Nombre': 'Alejandro'}
# Edad:  22
# {'Nombre': 'Alejandro', 'Edad': '22'}
# Sexo:  Masculino
# {'Nombre': 'Alejandro', 'Edad': '22', 'Sexo': 'Masculino'}
# Teléfono:  09999999
# {'Nombre': 'Alejandro', 'Edad': '22', 'Sexo': 'Masculino', 'Teléfono': '09999999'}
# Correo:  puce.edu.ec
# {'Nombre': 'Alejandro', 'Edad': '22', 'Sexo': 'Masculino', 'Teléfono': '09999999', 'Correo': 'puce.edu.ec'}
