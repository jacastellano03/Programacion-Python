# %%
# Escribir un programa que pregunte al usuario una cantidad a invertir, el interés anual y el número de años, y muestre por pantalla el capital obtenido en la inversión.

cant_inv = float(input("Ingrese el monto que desea invertir: "))
interest_rate = float(input("Ingrese el interés anual: "))
number_of_years = int(input("Ingrese el número de años: "))

Ending_Capital = (cant_inv * (1+(interest_rate/100))**number_of_years)
print(round(Ending_Capital, 2))
# Out:
# Ingrese el monto que desea invertir:  1000
# Ingrese el interés anual:  10
# Ingrese el número de años:  5
# 1610.51
