# %%
# Ejercicio 4
# Los teléfonos de una empresa tienen el siguiente formato prefijo-número-extension donde el prefijo es el código del país +34, y la extensión tiene dos dígitos (por ejemplo +34-913724710-56). Escribir un programa que pregunte por un número de teléfono con este formato y muestre por pantalla el número de teléfono sin el prefijo y la extensión.
'''
pref = str(input("Ingrese el prefijo del numero:"))
telefono = int(input("Ingrese el numero de telefono:"))
ext = str(input("Ingrese el extension  del numero:"))

print("El numero completo es:",pref,telefono,ext)

print("El numero telefonico es:",telefono)
'''
num = str(input("Ingrese el numero de telefono:"))          #Tambien se puede hacer sin el str para que el ejercicio se vea mas limpio

print(num[4:13])
# Out:
# Ingrese el numero de telefono: +34-913724710-56
# 913724710
