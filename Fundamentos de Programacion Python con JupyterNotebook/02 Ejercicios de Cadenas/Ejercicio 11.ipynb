# %%
# Ejercicio 11
# Escribir un programa que pregunte el nombre el un producto, su precio y un número de unidades y muestre por pantalla una cadena con el nombre del producto seguido de su precio unitario con 6 dígitos enteros y 2 decimales, el número de unidades con tres dígitos y el coste total con 8 dígitos enteros y 2 decimales.

name_product = input("Ingrese el nombre del producto:")
price = float(input("Ingrese el precio del producto:"))
unidades = int(input("Ingrese el numero de unidades del producto:"))

print("Forma 1")
price = round(price, 2)
costo_total = (unidades * price)
costo_total = round(costo_total, 2)

print("El nombre del producto es",name_product,"su precio por unidad es de",price,"el costo total es de:",costo_total)

print("Forma 2")
costo_total2 = (unidades * price)                              #09 espacios llenados  con 0, (2f) 2 decimales y f quiere decir float

print(f"El producto es {name_product}, su precio por unidad es {price:09.2f},$ y el costo total es de {costo_total2:011.2f}$")
# Out:
# Ingrese el nombre del producto: Gelatina
# Ingrese el precio del producto: 27.80
# Ingrese el numero de unidades del producto: 12
# Forma 1
# El nombre del producto es Gelatina su precio por unidad es de 27.8 el costo total es de: 333.6
# Forma 2
# El producto es Gelatina, su precio por unidad es 000027.80,$ y el costo total es de 00000333.60$
