# %%
# Ejercicio 3
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla <NOMBRE> tiene <n> letras, donde <NOMBRE> es el nombre de usuario en mayúsculas y <n> es el número de letras que tienen el nombre.

username = str(input("Ingrese el nombre de usuario:"))

username = username.upper()

print("Su usuario es:",username)
print("Número de letras que tienen el nombre:",len(username))
# Out:
# Ingrese el nombre de usuario: alejandro
# Su usuario es: ALEJANDRO
# Número de letras que tienen el nombre: 9
